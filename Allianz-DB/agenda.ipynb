# %%
databricks sql ( ai features ) bi, self services feature (done)
databricks repo, cli command)
connect to power bi 


dabs cicd
pipeline end to end
unity catalog
delta sharing
lakehouse federation 
spark optmization

# %%
pipeline end to end
1. manual
2. genie code
