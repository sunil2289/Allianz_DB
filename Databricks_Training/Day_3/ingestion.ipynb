# %%
# %run "/Workspace/Users/sunil.sukumaran@allianz.com/Databricks_Training/Day_3/includes"

# %%
dbutils.widgets.text("catalog","dev")
dbutils.widgets.text("table_name","default")

# %%
catalog=dbutils.widgets.get("catalog")
table_name=dbutils.widgets.get("table_name")

# %%
df=(spark.read.csv(f"{input_path}{table_name}/",header=True,inferSchema=True))
df1=add_columns(df)
df1.write.mode("overwrite").saveAsTable(f"{catalog}.sunil_bronze.{table_name}")
