# %%
# %sql
insert into dev.naval.emp values (5,'Sunil','Kerala')

# %% [markdown]
# %python
# Lakehouse: Data Lake + Data warehouse
#
# Build lakehouse by delta, iceberg

# %%
# %sql
create table dev.sunil.employee (id int, name string, city string);

# %%
# %sql
desc extended dev.sunil.employee

# %%
# %sql
desc detail dev.sunil.employee

# %%
# %sql
desc history dev.sunil.employee

# %%
# %sql
insert into dev.sunil.employee values (1,'Sunil','Trivandrum')

# %%
# %sql
insert into dev.sunil.employee values (2,'Shine','kerala'),(3,'Unni','Bengaluru')

# %%
# %sql
select * from dev.sunil.employee

# %%
# %sql
update dev.sunil.employee
set city ='Delhi'
where id = 1

# %%
# %sql
SELECT * FROM dev.sunil.employee VERSION AS OF 2

# %%
# %sql
delete from dev.sunil.employee

# %% [markdown]
# ##Restore

# %%
# %sql
restore table dev.sunil.employee to version as of 2

# %%
# %sql
select * from dev.sunil.employee
