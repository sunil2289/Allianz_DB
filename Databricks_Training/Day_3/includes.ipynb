# %%
# %sql
create schema if not exists dev.sunil_bronze;
create schema if not exists dev.sunil_silver;
create schema if not exists dev.sunil_gold;

# %%
# %python
input_path="/Volumes/dev/naval/project/"

# %%
# %python
from pyspark.sql.functions import *

# %%
# %python
def add_columns(df):
    return df.withColumn("ingestion_date",current_timestamp()).withColumn("path",col("_metadata.file_name"))
