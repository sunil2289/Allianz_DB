# %%
# %sql
create or replace view dev.sunil_gold.top_customers as 
select customer_id, sum(total_amount) as total from dev.sunil_silver.sales_cleaned group by customer_id order by total desc limit 3

# %%
# %sql
select * from dev.sunil_gold.top_customers
