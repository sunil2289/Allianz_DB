# %%
# %sql
create table dev.sunil.sales_b as 
select * from read_files ("/Volumes/dev/naval/project/sales/sales.csv")

# %%
# %sql
create table if not exists dev.sunil.sales_b as 
select * from read_files ("/Volumes/dev/naval/project/sales/sales.csv")

# %%
# %sql
create or replace table dev.sunil.sales_b as 
select * from read_files ("/Volumes/dev/naval/project/sales/")

# %%
# %sql
select * from dev.sunil.sales_b

# %%
# %sql
insert into dev.sunil.sales_b (select order_id, customer_id, transaction_id, product_id, quantity, discount_amount, total_amount, to_date(order_date, 'MM/dd/yy') as order_date, NULL as order_date_2 from read_files ("/Volumes/dev/naval/project/sales/"))

# %%
# %sql
select * from dev.sunil.sales_b

# %%
# %sql
CREATE TABLE IF NOT EXISTS <catalog>.<schema>.booking_updates_schemaless;

COPY INTO <catalog>.<schema>.booking_updates_schemaless
FROM '/Volumes/<catalog>/<schema>/<volume>/wanderbricks/booking_updates'
FILEFORMAT = JSON
FORMAT_OPTIONS ('mergeSchema' = 'true', 'multiLine' = 'true')
COPY_OPTIONS ('mergeSchema' = 'true');

# %%
# %sql
create table if not exists dev.sunil.sales_copy (order_id int, customer_id int , transaction_id int, product_id int, quantity int, discount_amount double, total_amount double, order_date string)

# %%
# %sql
create table if not exists dev.sunil.month_copy

# %%
# %sql
COPY INTO dev.sunil.month_copy 
FROM '/Volumes/dev/naval/project/incremental/'
FILEFORMAT = CSV
FORMAT_OPTIONS ('header' = 'true')
COPY_OPTIONS ('mergeSchema' = 'true');

# %%
# %sql
select * from dev.sunil.month_copy
