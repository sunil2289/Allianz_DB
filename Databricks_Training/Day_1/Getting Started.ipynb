# %% [markdown]
# ##Getting Started

# %% [markdown]
# print("hello world")

# %% [markdown]
# ##Types of Computes
# 1.All Purpose
# 2.Job
# 3.Serverless
# 4.Serverless SQL warehouse

# %%
# %sql
select * from samples.tpch.orders
order by o_orderpriority;

# %%
# %sql
select * from samples.tpch.orders;

# %%
# %sql

# %%
# %sql
