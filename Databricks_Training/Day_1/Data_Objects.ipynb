# %%
# %sql
create schema dev.sunil

# %%
# %sql
create table dev.sunil.demo (id int primary key,name string)

# %%
# %sql
insert into dev.sunil.demo values(4,'Yash')

# %%
# %sql
select * from  dev.sunil.demo;

# %%
# %sql
insert into dev.sunil.demo values (1,'Sunil');
select * from  dev.sunil.demo (1,'Sunil')

# %% [markdown]
# ![](path)

# %% [markdown]
# ![](/Volumes/dev/naval/raw/object-model.png)

# %% [markdown]
# ![]()

# %% [markdown]
# ![](/Volumes/dev/sunil/sunil_volume/Butterfly.jpg)

# %% [markdown]
# ![](/Volumes/dev/sunil/sunil_volume/Butterfly.jpg)

# %% [markdown]
# ![](/Volumes/dev/anumohan/customer/medellion architecture.png)

# %% [markdown]
# ![](/Volumes/dev/sunil/sunil_volume/Butterfly.jpg)
