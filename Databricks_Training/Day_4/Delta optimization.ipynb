-- %%
select * from dev.sunil.employee --where id =1

-- %%
desc history dev.sunil.employee

-- %%
desc extended dev.sunil.employee

-- %%
desc detail dev.sunil.employee

-- %%
30 files
6 are in use
24 stale

select * where id =1 >>>> 4 files

-- %%
insert into dev.sunil.employee values (10,'Shine', 'Delhi');
insert into dev.sunil.employee values (11,'Mine', 'Mumbai');
insert into dev.sunil.employee values (12,'Ram', 'Pune');
insert into dev.sunil.employee values (13,'Steve', 'Ranchi');
insert into dev.sunil.employee values (14,'John', 'Chennai');

-- %%
Delta Optimization 


1. Query performance  (increase)

-- optimize : converts small/tiny files into large file 
    --   z order ( indexing)
    ---  liquid cluster (auto)

2. Storage cost (decrease).
--- vacuum : deletes all stale files ( NO TIME travel) --- retentiond period by default is 7 days = 168 hours

-- %%
 optimize dev.sunil.employee
 zorder by (id)

-- %%
vacuum dev.sunil.employee

-- %%
select * from dev.sunil.employee

-- %%
vacuum dev.sunil.employee retain 0 hours

-- %%
ALTER TABLE dev.sunil.employee SET TBLPROPERTIES ('delta.deletedFileRetentionDuration' = 'interval 0 hours')

-- %%
SET spark.databricks.delta.retentionDurationCheck.enabled = false

-- %%
create table dev.sunil.cust (id int, name string) location 's3://jpmctraining/allianz/sunil'

-- %%
select * from dev.sunil.cust;

-- %%
insert into dev.sunil.cust values (10,'Sunil');

-- %%
select * from delta.`s3://jpmctraining/allianz/sunil`

-- %%
drop table dev.sunil.cust ;

-- %%
CREATE OR REPLACE TABLE dev.sunil.emp_clone_shallow
SHALLOW CLONE dev.sunil.employee;

-- %%
CREATE OR REPLACE TABLE dev.sunil.emp_clone_deep
DEEP CLONE dev.sunil.employee;

-- %%
delete from dev.sunil.emp_clone_shallow --where id= 10

-- %%
desc history dev.sunil.emp_clone_shallow
